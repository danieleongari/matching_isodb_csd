# %% [markdown]
# # Match by DOI

# %%
import pandas as pd
import pickle 
from tqdm import tqdm
import json

# %%
with open("data/nistdb.pickle", 'rb') as f:
    nistdb = pickle.load(f)
    
with open("data/csd_542_mofchecker.json", "r") as file:
    mof_checker = json.load(file)

mof_checker['FIQCEN']
# Out:
# {'asr': {'name': 'FIQCEN',
#   'graph_hash': '521324a26079f95c5a55e7f417c3fa7f',
#   'scaffold_hash': 'e1682de934a12384f1952d34148e3832',
#   'symmetry_hash': 'mEopNc0Bbry+C0Mp9WB7PJqumiUvMB4qfFQS9GqwjvI=225',
#   'formula': 'Cu12 H24 C72 O48',
#   'path': None,
#   'density': 0.879095741266423,
#   'has_carbon': True,
#   'has_hydrogen': True,
#   'has_atomic_overlaps': True,
#   'has_overcoordinated_c': False,
#   'has_overcoordinated_n': False,
#   'has_overcoordinated_h': False,
#   'has_undercoordinated_c': False,
#   'has_undercoordinated_n': False,
#   'has_undercoordinated_rare_earth': False,
#   'has_metal': True,
#   'has_lone_molecule': False,
#   'has_high_charges': True,
#   'is_porous': None,
#   'has_suspicicious_terminal_oxo': False},
#  'fsr': {'name': 'FIQCEN',
#   'graph_hash': '7476b78aa05f38eafe32f4305b186a38',
#   'scaffold_hash': '28d2fe83c2312ed56ab28a947e4bdad4',
#   'symmetry_hash': 'XJpP2YtrKA/2eBwUPtWVkjwWOBwL2pI4SqWbrbxLluU=225',
#   'formula': 'Cu12 H24 C72 O60',
#   'path': None,
#   'density': 0.9488544343069328,
#   'has_carbon': True,
#   'has_hydrogen': True,
#   'has_atomic_overlaps': True,
#   'has_overcoordinated_c': False,
#   'has_overcoordinated_n': False,
#   'has_overcoordinated_h': False,
#   'has_undercoordinated_c': False,
#   'has_undercoordinated_n': False,
#   'has_undercoordinated_rare_earth': False,
#   'has_metal': True,
#   'has_lone_molecule': False,
#   'has_high_charges': True,
#   'is_porous': None,
#   'has_suspicicious_terminal_oxo': True},
#  'orig': {'name': 'FIQCEN',
#   'graph_hash': '7476b78aa05f38eafe32f4305b186a38',
#   'scaffold_hash': '28d2fe83c2312ed56ab28a947e4bdad4',
#   'symmetry_hash': '6ZlWMo2/wtbv0gdN7tWjtOwrVUO+r/tisLjwydvqGMk=225',
#   'formula': 'Cu12 H24 C72 O84',
#   'path': None,
#   'density': 1.0883718209493567,
#   'has_carbon': True,
#   'has_hydrogen': True,
#   'has_atomic_overlaps': True,
#   'has_overcoordinated_c': False,
#   'has_overcoordinated_n': False,
#   'has_overcoordinated_h': False,
#   'has_undercoordinated_c': False,
#   'has_undercoordinated_n': False,
#   'has_undercoordinated_rare_earth': False,
#   'has_metal': True,
#   'has_lone_molecule': True,
#   'has_high_charges': True,
#   'is_porous': None,
#   'has_suspicicious_terminal_oxo': True}}

# %%
# Add a column with nist_mat matched by doi

df = pd.read_csv("data/step-04.csv")

for pub in nistdb['Bibliography']:
    pub['DOI'] = pub['DOI'].lower() # NOTE: I already lowered all DOIs from CSD

for i, doi_csd in enumerate(tqdm(df['publication_doi'])): # takes 1 minute
    if not doi_csd: # Missing DOI
        continue
    for pub in nistdb['Bibliography']:
        doi_nist = pub['DOI']
        if doi_csd==doi_nist:
            df.at[i,"nist_mat_by_doi"] = str(pub['adsorbentMaterial']) # NOTE 1: adsorbentMaterial will be always the main name for NIST, not a synonym (e.g., no HKUST-1, only CuBTC)
            break                                                      # NOTE 2: pub['adsorbentMaterial'] is a list that may contain more entries if the paper contains more materials!
df.to_csv("data/step-05.csv", index=False) 
# step-05.csv: add column nist_mat_by_doi with possible matches but not performing the match yet
# Out:
# 100%|█████████████████████████████████| 105922/105922 [00:49<00:00, 2154.41it/s]

# %%
df = pd.read_csv("data/step-05.csv")
df[~pd.isna(df.nist_mat_by_doi)].head(3)
# Out:
#     identifier  ccdc_number  \
# 34      ABEMIF     833721.0
# 195     ACAJIZ     853983.0
# 196     ACAJOF     853984.0
#
#                                                formula  has_disorder  \
# 34   (C2 H8 N1 1+)3n,n(C72 H24 Cl3 Cu12 O48 3-),9n(...          True
# 195                   (C22 H24 Cu2 N2 O8)n,n(C2 H3 N1)          True
# 196                   (C23 H26 Cu2 N2 O8)n,n(C3 H6 O1)         False
#
#      publication_year     publication_doi synonyms_orig synonyms note  \
# 34               2011  10.1039/c1cc14118j            []       []    -
# 195              2012  10.1039/c2dt31427d            []       []    -
# 196              2012  10.1039/c2dt31427d            []       []    -
#
#     nist_mat                                    nist_mat_by_doi
# 34       NaN  ['[(CH3)NH2]3[(Cu4Cl)3-(btc)8].xMeOH', '[(CH3)...
# 195      NaN  ['{Cu2(Glu)2(mu-bpa)}*(CH3CN)', '{Cu2(Glu)2(mu...
# 196      NaN  ['{Cu2(Glu)2(mu-bpa)}*(CH3CN)', '{Cu2(Glu)2(mu...

# %%
# Showing (but not doing anything) possible names that need correction: 
#   they match DOI and have CSD synonyms, but their synonyms are not matching
df = pd.read_csv("data/step-05.csv")
df = df[(df['note']=='-') & ~pd.isnull(df['nist_mat_by_doi']) & (df['synonyms']!='[]')]
df[['identifier','publication_doi','synonyms','nist_mat_by_doi']].reset_index()
# Out:
#      index identifier         publication_doi  \
# 0      292     ACOCOM      10.1039/c2cc34840c
# 1      293     ACOCUS      10.1039/c2cc34840c
# 2      295     ACODAZ      10.1039/c2cc34840c
# 3      537     ADOGEH      10.1039/c2cc36220a
# 4     1636     ALAMUW  10.1002/chem.201002135
# ..     ...        ...                     ...
# 78   98691     XUPSAE      10.1038/nchem.2114
# 79  102337     YUBFIL       10.1021/ic802446m
# 80  102338     YUBFOR       10.1021/ic802446m
# 81  102339     YUBFUX       10.1021/ic802446m
# 82  102340   YUBFUX01       10.1021/ic802446m
#
#                               synonyms  \
# 0                       ['DUT-49(Cu)']
# 1                       ['DUT-49(Zn)']
# 2                       ['DUT-49(Co)']
# 3                           ['UHM-30']
# 4                           ['SNU-50']
# ..                                 ...
# 78  ['NOTT-300 deuteroethane solvate']
# 79                          ['MAF-X3']
# 80                          ['MAF-X4']
# 81                          ['MAF-X5']
# 82                          ['MAF-X6']
#
#                             nist_mat_by_doi
# 0                                ['DUT-49']
# 1                                ['DUT-49']
# 2                                ['DUT-49']
# 3                          ['Cu3(NH2btc)2']
# 4                         ['C26H8Cu2N2O12']
# ..                                      ...
# 78                             ['NOTT-300']
# 79  ['C5.33H8.67N3.17O2.25Zn', 'C4H6FN3Zn']
# 80  ['C5.33H8.67N3.17O2.25Zn', 'C4H6FN3Zn']
# 81  ['C5.33H8.67N3.17O2.25Zn', 'C4H6FN3Zn']
# 82  ['C5.33H8.67N3.17O2.25Zn', 'C4H6FN3Zn']
#
# [83 rows x 5 columns]

# %%
# Flag the ones with multiple NIST-ISODB adsorbents, but if unique add them to the nist_mat
df = pd.read_csv("data/step-05.csv")

for row in tqdm(df.itertuples(), total=df.shape[0]):
    if row.note.startswith("Matched by synonym"):
        continue
    elif row.note=="Exclude DOI already matched by synonym":
        continue        
    elif row.note=="Excluding more than 3 same MOFs from the same DOI":
        continue
    elif pd.isnull(row.nist_mat_by_doi):
        continue
        
    else:
        synonyms = eval(row.nist_mat_by_doi)
        if len(synonyms)==1: # Only one nist-isodb
            df.at[row.Index,"nist_mat"] = synonyms[0]
            if len(df[df.publication_doi==row.publication_doi])==1: # check if there are multiple CSD from the same DOI
                df.at[row.Index,"note"] = "One-to-one match by DOI"
            else:
                df.at[row.Index,"note"] = "OneNIST-to-manyCSD matches by DOI (to check)"
                
        # Third choice, if there is >one nist_adsorbent_by_doi, write them all and mark that there is need for revision
        else:
            df.at[row.Index,"note"] = "VariousNIST-to-paper matched by DOI"

df.to_csv("data/step-06.csv", index=False) 
# step-06.csv: add nist_mat for unique match, and "note": still need to check for multiple CSD
# Out:
# 100%|████████████████████████████████| 105922/105922 [00:04<00:00, 23766.22it/s]

# %%
df = pd.read_csv("data/step-06.csv")
df[~pd.isna(df.nist_mat_by_doi)].head(3)
# Out:
#     identifier  ccdc_number  \
# 34      ABEMIF     833721.0
# 195     ACAJIZ     853983.0
# 196     ACAJOF     853984.0
#
#                                                formula  has_disorder  \
# 34   (C2 H8 N1 1+)3n,n(C72 H24 Cl3 Cu12 O48 3-),9n(...          True
# 195                   (C22 H24 Cu2 N2 O8)n,n(C2 H3 N1)          True
# 196                   (C23 H26 Cu2 N2 O8)n,n(C3 H6 O1)         False
#
#      publication_year     publication_doi synonyms_orig synonyms  \
# 34               2011  10.1039/c1cc14118j            []       []
# 195              2012  10.1039/c2dt31427d            []       []
# 196              2012  10.1039/c2dt31427d            []       []
#
#                                     note nist_mat  \
# 34   VariousNIST-to-paper matched by DOI      NaN
# 195  VariousNIST-to-paper matched by DOI      NaN
# 196  VariousNIST-to-paper matched by DOI      NaN
#
#                                        nist_mat_by_doi
# 34   ['[(CH3)NH2]3[(Cu4Cl)3-(btc)8].xMeOH', '[(CH3)...
# 195  ['{Cu2(Glu)2(mu-bpa)}*(CH3CN)', '{Cu2(Glu)2(mu...
# 196  ['{Cu2(Glu)2(mu-bpa)}*(CH3CN)', '{Cu2(Glu)2(mu...

# %%
# Show statistics
df = pd.read_csv("data/step-06.csv")
df = df.sort_values('note', ascending=True) # When I keep=first, these are sorted by note

print('Statistics by CSD entries')
for note in df['note'].unique():
    count = len(df[df.note==note])
    print(count, "\t",note)
    
print('\nStatistics by Paper')
df1 = df[~pd.isnull(df['publication_doi'])]
df1 = df1[~df1.duplicated(subset='publication_doi', keep='first')]

for note in df['note'].unique():
    count = len(df1[df1.note==note])
    print(count, "\t",note)
    
print('\nStatistics by NIST matches')
df = df[~pd.isnull(df['nist_mat'])]
df = df[~df.duplicated(subset='nist_mat', keep='first')]

tot = 0
for note in df['note'].unique():
    count = len(df[df.note==note])
    tot+=count
    print(count, "\t",note)
print(tot, "\t","TOTAL")
    
print("\nNOTE: You can find some little mismatch in the NIST stats because df.duplicates() may remove rows from different categories,")
print("       but I used df.sort_values and ascending Notes to avoid it.")
# Out:
# Statistics by CSD entries
# 101360 	 -
# 370 	 Exclude DOI already matched by synonym
# 1913 	 Excluding more than 3 same MOFs from the same DOI
# 394 	 Matched by synonym
# 40 	 Matched by synonym (corrected)
# 325 	 One-to-one match by DOI
# 583 	 OneNIST-to-manyCSD matches by DOI (to check)
# 937 	 VariousNIST-to-paper matched by DOI
#
# Statistics by Paper
# 42919 	 -
# 70 	 Exclude DOI already matched by synonym
# 8 	 Excluding more than 3 same MOFs from the same DOI
# 159 	 Matched by synonym
# 22 	 Matched by synonym (corrected)
# 325 	 One-to-one match by DOI
# 165 	 OneNIST-to-manyCSD matches by DOI (to check)
# 330 	 VariousNIST-to-paper matched by DOI
#
# Statistics by NIST matches
# 302 	 Matched by synonym
# 32 	 Matched by synonym (corrected)
# 319 	 One-to-one match by DOI
# 157 	 OneNIST-to-manyCSD matches by DOI (to check)
# 810 	 TOTAL
#
# NOTE: You can find some little mismatch in the NIST stats because df.duplicates() may remove rows from different categories,
#        but I used df.sort_values and ascending Notes to avoid it.

# %%
# Add structure SGH (Structure Graph Hash) for AllSolventRemoved structures
df = pd.read_csv("data/step-06.csv")

missing = 0
for i, csd_id in enumerate(tqdm(df['identifier'])):
    try:
        graph = mof_checker[csd_id]['asr']['graph_hash']
    except:
        missing+=1
        graph = "MISSING_" + csd_id   
    df.at[i, 'sgh_asr'] = graph

print('Missing SGH:', missing)
df.to_csv("data/step-07.csv", index=False) 
# step-07.csv: add SGH
# Out:
# 100%|███████████████████████████████| 105922/105922 [00:00<00:00, 162402.08it/s]
# Missing SGH: 1128

# %%
df = pd.read_csv("data/step-07.csv")
df.head(3)
# Out:
#   identifier  ccdc_number                formula  has_disorder  \
# 0     ABACUF    1100034.0  (C6 H14 Ba2 Cu1 O16)n         False
# 1   ABACUF01     230290.0  (C6 H14 Ba2 Cu1 O16)n         False
# 2     ABAFUH    1498688.0        (C9 H8 Cu2 O4)n         False
#
#    publication_year                 publication_doi synonyms_orig synonyms  \
# 0              1958                             NaN            []       []
# 1              2004  10.1016/j.molstruc.2004.03.051            []       []
# 2              2016      10.1016/j.poly.2016.09.043            []       []
#
#   note nist_mat nist_mat_by_doi                           sgh_asr
# 0    -      NaN             NaN  e15bb6793b1e615a15d2086631ee9290
# 1    -      NaN             NaN  4a5274dbb47d6011b4ac1b11f5066f27
# 2    -      NaN             NaN  2eac7429e128fbdb695d7980ce88563a

# %%
# Identify if CSD structures linked to the same papers are actually the same once desolvated (ASR)

PRINT = True    

df = pd.read_csv("data/step-07.csv")
df_to_check = df[df['note'] == "OneNIST-to-manyCSD matches by DOI (to check)"]

# Loop over the papers with same DOI
all_identifiers = []
for i, doi in enumerate(set(df_to_check['publication_doi'])):
    df_same_doi = df[df['publication_doi'] == doi]
    nist_mat = df_same_doi['nist_mat'].values[0]
    all_identifiers+= list(df_same_doi['identifier'].values)
    if PRINT: print(i, nist_mat, doi)
    graphs = df_same_doi['sgh_asr'].values
    if all([x==graphs[0] for x in graphs]):
        if PRINT: print(' >>> ALL THE SAME!', *df_same_doi['identifier'].values)
        for index in df_same_doi.index:
            df.at[index, "note"] = "OneNIST-to-manyCSD matches by DOI >> MATCH, same SGH"
    else:
        if PRINT: print(' >>> SOME DIFFERENT, REMOVE!', *df_same_doi['identifier'].values)
        
        for index in df_same_doi.index:
            df.at[index, 'nist_mat'] = None
            df.at[index, "note"] = "OneNIST-to-manyCSD matches by DOI >> EXCLUDE, different SGH"

df.to_csv("data/step-08.csv", index=False) 
# data/step-08.csv: filter entries with multiple
# Out:
# 0 [Cd(PDCO)(bipy)*(H2o)*5H2O]n 10.1016/j.inoche.2008.09.002
#  >>> SOME DIFFERENT, REMOVE! NONWUJ NONXAQ
# 1 C40H26CoN8O6S2 10.1021/ja039914m
#  >>> SOME DIFFERENT, REMOVE! AVUBAU AVUBEY AVUBIC
# 2 [Ni2(NCS)4(azpy)4]n 10.1021/ic061052d
#  >>> SOME DIFFERENT, REMOVE! XESBED XESBIH XETNUG XETPAO XETPES
# 3 [Zn3L2(HCOO)1.5][(CH3)2NH2]1.5 xDMF 10.1039/c4ta01993h
#  >>> SOME DIFFERENT, REMOVE! HOKLIE HOKLOK
# 4 [Zn3-(ntb)2]n 10.1002/chem.200601534
#  >>> ALL THE SAME! PIDMEV PIDMEV01 PIFPIE
# 5 C99H72Cd6O42 10.1021/cg101222w
#  >>> SOME DIFFERENT, REMOVE! AROFAP AROFET EREGOY
# 6 ABT*2ClO4 10.1002/anie.201307650
#  >>> SOME DIFFERENT, REMOVE! YIKJOT YIKJUZ
# 7 MIL-53(Cr) 10.1039/c0cc03882b
#  >>> ALL THE SAME! GUSNEN01 QALGUH
# 8 C15H13O13La 10.1021/cg100078b
#  >>> SOME DIFFERENT, REMOVE! RUWWOW RUWWOW01 RUWWUC RUWXAJ RUWXEN RUWXOX
# 9 RIWMUH 10.1039/c3ce41428k
#  >>> SOME DIFFERENT, REMOVE! RIWMUH RIWNAO RIWQIZ RIWQOF
# 10 [Zn(TeGly)]n 10.1039/c5nj00011d
#  >>> SOME DIFFERENT, REMOVE! REYNOA01 REYNUG01
# 11 C4N8O4Cd2 10.1039/c0cc03506h
#  >>> SOME DIFFERENT, REMOVE! UMELUU UMEMAB
# 12 NH2-MIL-53(Al) 10.1002/cssc.201100378
#  >>> SOME DIFFERENT, REMOVE! NAXKOO NAXKOO01 NAXKOO02 NAXLEF
# 13 DUT-8(Ni) 10.1039/c5cp02180d
#  >>> SOME DIFFERENT, REMOVE! VUKRIE VUKROK VUKRUQ VUKSAX
# 14 [{Fe(NCS)2}3(TPB)4] 10.1039/c3cc45180a
#  >>> SOME DIFFERENT, REMOVE! TIJMOQ TIJMOQ01
# 15 C10H11FeN3O7 10.1021/cg801321e
#  >>> SOME DIFFERENT, REMOVE! FUFREE FUFRII FUFROO FUFRUU FUFSAB FUFSEF
# 16 Fe3[(Fe4Cl)3(BTT)8(MeOH)4]2 10.1039/c0sc00179a
#  >>> SOME DIFFERENT, REMOVE! GAGQAI MUWQEB
# 17 Desolvated C4H4N6Cu 10.1039/c2dt12311h
#  >>> ALL THE SAME! CAYBAH CAYBAH01
# 18 Cu2-Framework 10.1002/chem.201503163
#  >>> SOME DIFFERENT, REMOVE! GAFROX GAFRUD
# 19 PCN-121 10.1039/c1cc16261f
#  >>> SOME DIFFERENT, REMOVE! XALMII XALMOO
# 20 MIL-53(Ga) 10.1039/b817563b
#  >>> SOME DIFFERENT, REMOVE! LOQLIN01 QOVWOO
# 21 DUT-49 10.1039/c2cc34840c
#  >>> SOME DIFFERENT, REMOVE! ACOCOM ACOCUS ACODAZ
# 22 Cd3C28H30N20O4 10.1039/b712485f
#  >>> SOME DIFFERENT, REMOVE! CITVOR CITVUX
# 23 C36H24Cu3N13O12 10.1021/acs.inorgchem.5b00561
#  >>> SOME DIFFERENT, REMOVE! QUJKUD QUJLAK QUJLAK01 QUJLAK02
# 24 [Cu3(bpac)3(CO3)2](ClO4)2 H2O 10.1039/c4dt02205j
#  >>> SOME DIFFERENT, REMOVE! YOPLOG YOPLUM
# 25 C36H12Cd3N0O34Tb2 10.1002/asia.201101002
#  >>> SOME DIFFERENT, REMOVE! TAZLAJ TAZLEN TAZLIR TAZLOX TAZLUD
# 26 437-MOF 10.1039/c4ta00963k
#  >>> ALL THE SAME! PODGEW PODGEW01 PODGEW02
# 27 [Zn5(mu3-OH)4L2]*7H2O*DMF 10.1039/c2cc36713k
#  >>> SOME DIFFERENT, REMOVE! XENMIO XENMOU
# 28 [Ag2(Me4bpz)] 10.1002/anie.200603270
#  >>> SOME DIFFERENT, REMOVE! YEVQOG YEVQUM YEYVII YEYVOO
# 29 IRMOF-1 10.1126/science.1113247
#  >>> SOME DIFFERENT, REMOVE! LATFOC LATFUI LAWFOF LAWFUL LAWGAS LAWGEW LAWGIA LAWGOG LAWGUM SAHYOQ02
# 30 [Zn(SiF6)(pyz)2]n 10.1002/ejic.200900144
#  >>> SOME DIFFERENT, REMOVE! FUDQAX FUDQEB FUDQIF
# 31 C40H54N4Ni2O21 10.1021/ja203053y
#  >>> SOME DIFFERENT, REMOVE! KALFEK KALFIO KALFOU KALFUA KALGAH KALGEL
# 32 CAU-13 10.1021/ic500288w
#  >>> SOME DIFFERENT, REMOVE! JIZWAS JIZWEW JIZWIA JIZWOG
# 33 Co3(HCOO)6 10.1002/adfm.200800058
#  >>> SOME DIFFERENT, REMOVE! ATIBOU01 YANBAR01
# 34 {[Zn3(DLlac)2(pybz)2]*2.5DMF}n 10.1021/ja908293n
#  >>> SOME DIFFERENT, REMOVE! LUVTAY LUVTEC
# 35 MIL-53(Cr) 10.1021/jp102463p
#  >>> SOME DIFFERENT, REMOVE! LURLOB LURMAO MINVUA02
# 36 La(H5DTMP) 10.1039/c2dt11992g
#  >>> ALL THE SAME! CAVSOJ CAVSUP CAVTAW
# 37 [Zn3(OH)2(btca)2] 10.1002/chem.201203515
#  >>> ALL THE SAME! LETRIN LETROT LETRUZ
# 38 mand-DUT-25 10.1016/j.micromeso.2015.02.055
#  >>> SOME DIFFERENT, REMOVE! UGEMIE UGEMOK
# 39 DynaMOF-100 10.1021/acs.inorgchem.5b00206
#  >>> SOME DIFFERENT, REMOVE! KULWAR KULWEV KULWIZ KUMJOT
# 40 (H2dab)[Zn2(ox)3] 10.1021/ja203291n
#  >>> SOME DIFFERENT, REMOVE! KALGIP KALGOV KALGUB
# 41 [Cu(INAIP)]*2H2O 10.1039/c0cc04689b
#  >>> ALL THE SAME! UNABUH UNABUH01 UNACES UNACIW
# 42 PCN-224 10.1021/ja5103103
#  >>> SOME DIFFERENT, REMOVE! NUSXAC NUSXEG
# 43 [Cu(pmc)2].2/3DMF 10.1021/ic1012523
#  >>> SOME DIFFERENT, REMOVE! AMAFIE AMAFOK AMAFUQ AMAGAX
# 44 Ni2(dhtp)(H2O)2*8H2O 10.1039/b515434k
#  >>> SOME DIFFERENT, REMOVE! LECQEQ LEJRIC
# 45 DUMMOP 10.1039/c5ce01192b
#  >>> SOME DIFFERENT, REMOVE! DUMMOP DUMMUV
# 46 {[Mn(L)(H2O)](H2O)1.5(DMF)}n 10.1021/ja9006035
#  >>> SOME DIFFERENT, REMOVE! LUFNAC LUFNAC01 LUFNAC02 LUFNAC03 LUFNAC04 LUFNAC05 LUFNEG LUFNIK LUFNOQ LUFNUW LUFPAE
# 47 [H2N(CH3)2][Zn3(TATB)2-(HCOO)]*HN(CH3)2*3DMF*3H2O 10.1021/ic0624773
#  >>> SOME DIFFERENT, REMOVE! PIBNUK PIBNUK01 PIBPAS PIBPAS01 PIBPEW PIBPEW01 PIBPIA
# 48 Fe2(dobdc) 10.1021/ja205976v
#  >>> SOME DIFFERENT, REMOVE! COKNOH01 GUVZEE GUVZII
# 49 Desolvated C35.50H31CoN3O9.50 10.1039/c2sc20443f
#  >>> SOME DIFFERENT, REMOVE! QEBGAH QEBGEL
# 50 C32H46N4O8Zn 10.1039/c2jm15604k
#  >>> SOME DIFFERENT, REMOVE! FECZEU FECZIY
# 51 C13H20N12O11Zn3 10.1021/cg100183y
#  >>> ALL THE SAME! WUXCAU WUXCEY
# 52 SBMOF-2 10.1021/jacs.5b02556
#  >>> SOME DIFFERENT, REMOVE! YUNJIC YUNJOI YUNJUO YUNKAV
# 53 C28H39N5O16Cu2 10.1021/cg201594p
#  >>> SOME DIFFERENT, REMOVE! DAWDOW DAWDUC DAWFAK FATLUJ
# 54 [(CH3)2NH2]2[Zn(TATAT)2/3]3DMFH2O 10.1002/adma.201102538
#  >>> ALL THE SAME! ICODIP ICODIP01
# 55 C99.50H120.50Cd4N15.50O35.50 10.1039/c1ce05099k
#  >>> SOME DIFFERENT, REMOVE! EYUKUF EYULAM EYULEQ EYULIU
# 56 [HSm{VO(TPPS)}]n 10.1039/c1dt10956a
#  >>> SOME DIFFERENT, REMOVE! RALZAH RALZEL
# 57 C36H20Co3N8O12 10.1021/ic101618n
#  >>> ALL THE SAME! ORUSUQ ORUSUQ01 ORUTAX
# 58 C32H24Cd2N6O12 10.1021/ja904363b
#  >>> SOME DIFFERENT, REMOVE! MUJRIT MUJROZ MUJSAM
# 59 C6H10CuN3 10.1021/ja800550a
#  >>> SOME DIFFERENT, REMOVE! BOBTIW BOBTOC BOBTUI BOGXIF BOGXOL
# 60 [KCo7(OH)3(ip)6(H2O)4]*12H2O 10.1002/adma.200700450
#  >>> SOME DIFFERENT, REMOVE! KISPOS KIXKOS
# 61 C12H18N2O16Zn2 10.1021/ja5022014
#  >>> ALL THE SAME! VOLXEB VOLXIF
# 62 [Cu2(pcp)2bipy]*5H2O]n 10.1039/c2ce26138c
#  >>> ALL THE SAME! CEKHAD CEKHEH
# 63 [(CH3)2NH2]2[Eu3+(μ3-OH)8(1,4-NDC)6(H2O)6]*(solv)x 10.1021/ja5131403
#  >>> SOME DIFFERENT, REMOVE! HUHZER HUHZIV
# 64 {[Co6(mu3-OH)2(IN)4-(HCOO)6]4DMF5H2O}n 10.1039/c3nj00236e
#  >>> SOME DIFFERENT, REMOVE! CEYPUT CIJBEE
# 65 C54H34CdCl6N10O14 10.1039/c2dt11815g
#  >>> SOME DIFFERENT, REMOVE! ZAXSUO ZAXTAV
# 66 {[Cu(bpy)2(OTf)2]*2EtOH*H2O} 10.1021/ja073568h
#  >>> ALL THE SAME! LITKIJ LITKOP LITKOP01
# 67 [Mg2(HCO2)2(NH2-BDC)(DMF)2] 10.1021/cg4000318
#  >>> ALL THE SAME! YICDAR YICDAR01
# 68 [Me2NH2][In(BPTC)] 10.1039/c5ce01376c
#  >>> SOME DIFFERENT, REMOVE! MUQYEE MURBEI
# 69 FMOF-1 10.1021/ja401671p
#  >>> SOME DIFFERENT, REMOVE! IFENOY IFENOY01 IFENOY02 IFENOY03 IFEPUG IFEQAN IFEQER IFEQIV
# 70 C78H54N18O13Zn4 10.1039/c1dt11431j
#  >>> ALL THE SAME! FANWIC FANWOI
# 71 [Zn2(TBC)2]2.3(H2O) 10.1039/c2jm15860d
#  >>> ALL THE SAME! FECWOB FECWOB01
# 72 MOF-705 10.1039/c5cc07578e
#  >>> SOME DIFFERENT, REMOVE! WUXYIZ WUXYOF WUXYUL WUXZAS
# 73 SNU-9 10.1039/b913067e
#  >>> ALL THE SAME! PUSDIR PUSDOX
# 74 [{Zn(L)(H2O)2}(NO3)2*2H2O]n 10.1002/anie.201206724
#  >>> SOME DIFFERENT, REMOVE! GEVRUW GEVSAD
# 75 [Mg(H2diol)(DMF)2] 10.1039/c3ce41253a
#  >>> SOME DIFFERENT, REMOVE! DIWMON DIWMUT DIWNAA
# 76 ([Co2(ade)(mu6-BTeC)(mu-H2O)(H2O)2]4(H2O) 10.1021/acs.cgd.5b00218
#  >>> SOME DIFFERENT, REMOVE! QUFKEJ QUFKIN
# 77 [Zn(TCNQ-TCNQ)bpy] 10.1038/nchem.684
#  >>> SOME DIFFERENT, REMOVE! MUVGOA MUVGUG MUVHAN MUVHER
# 78 C30H36N4CuF12O2P2 Desolvated 10.1021/ic0609249
#  >>> SOME DIFFERENT, REMOVE! PEVTIU PEVTOA PEVTUG PEVVAO PEVVES PEVVIW
# 79 NOTT-300 10.1038/nchem.1457
#  >>> SOME DIFFERENT, REMOVE! KUKWAR KUKWEV KUKWIZ
# 80 C24H21In3N4O22 10.1002/anie.200604306
#  >>> SOME DIFFERENT, REMOVE! RIDCAJ RIDCEN
# 81 [Fe(btzx)3](ClO4)2 10.1021/ja407135k
#  >>> ALL THE SAME! HINTOP HINVAD HINVAD01
# 82 C9H25N37O11Cu5 10.1021/cg901128k
#  >>> SOME DIFFERENT, REMOVE! PURSUR PURTAY PURTEC
# 83 Zn2(Atz)2(ox) 10.1126/science.1194237
#  >>> SOME DIFFERENT, REMOVE! WALBOC WALBOC01 WALBOC02 WALCET WALCIX
# 84 IRMOF-1 10.1021/ja0675447
#  >>> SOME DIFFERENT, REMOVE! HIFTOG HIFTOG01 HIFTOG02
# 85 SNU-6 10.1002/chem.200801064
#  >>> SOME DIFFERENT, REMOVE! HOHMEX HOHMIB ROGMEG
# 86 Cu4(OH)2(C8H3O7S)2 10.1038/nchem.254
#  >>> SOME DIFFERENT, REMOVE! GIKMOD01 HUCBOX HUCBUD
# 87 C31H32Cl4Co3N10O3 10.1039/c0cc04089d
#  >>> SOME DIFFERENT, REMOVE! EJEKIO EJEKOU EJEKOU01 EJELAH
# 88 [Zn(Gly-Thr)2]*CH3OH 10.1002/anie.201203929
#  >>> ALL THE SAME! NELWOS NELWUY
# 89 [Zn3L2(btc)2(H2O)] 10.1039/c3ce41002a
#  >>> SOME DIFFERENT, REMOVE! FIHHOV FIHHUB
# 90 C39H21Co3N3O19 10.1002/chem.201201559
#  >>> ALL THE SAME! RECHUE RECJAM
# 91 C40.5H32.5N11.5O9.5Zn2 10.1038/nmat2808
#  >>> SOME DIFFERENT, REMOVE! YUSPOS YUSPUY
# 92 Desolvated C76H56Cl4Hg4N20O8S4 10.1016/j.poly.2006.09.008
#  >>> SOME DIFFERENT, REMOVE! PIBFEM PIBFIQ
# 93 {[Zn2(L)(OH)]*2DMF*H2O}n 10.1021/ic202624e
#  >>> SOME DIFFERENT, REMOVE! KEDPUG KEDQAN
# 94 Co-Py2PO 10.1039/c4qi00138a
#  >>> SOME DIFFERENT, REMOVE! YOVXAK YOVXEO
# 95 {[Cd(pzbtz)]3H2O}n 10.1039/c4dt03129f
#  >>> SOME DIFFERENT, REMOVE! XORGOC XORGUI XORHET
# 96 C40H20Zn2N4O12 10.1038/ncomms1170
#  >>> SOME DIFFERENT, REMOVE! OJIWAG OJIWEK OJIWIO
# 97 {[Cu2(4-pmpmd)2(CH3OH)4(opd)2]*2H2O} 10.1021/cg3017563
#  >>> ALL THE SAME! TEWFOS TEWFUY TEWFUY01 TEWGEJ TEWGEJ01
# 98 DMF 10.1021/ic302641v
#  >>> SOME DIFFERENT, REMOVE! SENWAL SENWEP SENWIT SENWOZ
# 99 [Zn2(fu-bdc)2(dabco)]n 10.1021/ja302991b
#  >>> SOME DIFFERENT, REMOVE! NEDTOH NEDTUN NEDVAV NEDVEZ NEDVID
# 100 (CuC8H10O6P2)*(H2O)x 10.1021/ja207606u
#  >>> SOME DIFFERENT, REMOVE! KASPIF KASPOL
# 101 [CuL(Me2NH)] 10.1039/c5dt00460h
#  >>> SOME DIFFERENT, REMOVE! TUJBUX TUJCAE
# 102 [Zn6(mu6-O)(TPO)2]-(NO3)4-3H2O 10.1021/ic402481b
#  >>> SOME DIFFERENT, REMOVE! NIYZIG NIYZOM
# 103 {Zn(L1)] DMF) infinity 10.1039/c4ra07128j
#  >>> SOME DIFFERENT, REMOVE! NOMQAJ01 VOJGOS
# 104 Desolvated PCM-14a 10.1039/c2dt12011a
#  >>> ALL THE SAME! CAVLIW CAVLOC
# 105 MCF-38 10.1021/ic102015g
#  >>> SOME DIFFERENT, REMOVE! OXANOR OXANUX OXAPAF OXAPEJ
# 106 NOTT-202a 10.1038/nmat3343
#  >>> SOME DIFFERENT, REMOVE! GAZZEO GAZZIS GAZZIS01 GAZZIS02 GAZZIS03 GAZZIS04 GAZZIS05 NEDLOZ
# 107 CPM-42 10.1021/acs.cgd.5b00358
#  >>> SOME DIFFERENT, REMOVE! BUKXUC BUKYAJ
# 108 [Zn2(bdc)(S-lac)(dmf)] 10.1039/c1cc16209h
#  >>> ALL THE SAME! SAKRAZ SAKRED
# 109 C17.5H21.5CuN2.5O7.5 10.1021/ic102188v
#  >>> SOME DIFFERENT, REMOVE! IXAJUN IXAKAU
# 110 Y4P12O36N12C42H84 10.1039/c0dt00233j
#  >>> SOME DIFFERENT, REMOVE! NADKAG NADKEK NADKIO
# 111 [Cu(2-pySO3)2-(bpy)]*H2O 10.1021/ic800050u
#  >>> ALL THE SAME! DOGJUF DOGJUF01 DOGKAM DOLCUD DOLDAK
# 112 PCP-N 10.1021/jacs.5b09666
#  >>> SOME DIFFERENT, REMOVE! ODEPOF ODEPUL ODEQAS ODEQEW
# 113 C14H18N4O11Cd2 10.1021/cg2002095
#  >>> SOME DIFFERENT, REMOVE! PATKOM PATKUS PATLAZ PATLED PATLON YELYIY02
# 114 [Rh2(bza)4(pyz)]n 10.1002/asia.200600317
#  >>> SOME DIFFERENT, REMOVE! QEVNAH QEVNEL QEVNIP QEVNOV QEYDOO
# 115 [NH2(CH3)2][Zn3(4-Pca)3(ade)].10DMF.8H2O 10.1002/chem.201406323
#  >>> SOME DIFFERENT, REMOVE! CUDPOI CUDPUO CUDQAV CUDQEZ
# 116 Cd(II)-MOF 10.1021/ic101756t
#  >>> SOME DIFFERENT, REMOVE! AMULOK AMULUQ AMUMAX AMUMEB AMUMIF AMUMOL
# 117 C32H24Cu3N6O12 10.1002/chem.200802730
#  >>> SOME DIFFERENT, REMOVE! GUXJUF GUXKAM
# 118 Fe2NiO(Piv)6(L)(H2O) 10.1016/j.jssc.2014.07.025
#  >>> ALL THE SAME! ZOZVIV ZOZVOB
# 119 C44H30O15Zn4 10.1021/cg201552g
#  >>> SOME DIFFERENT, REMOVE! DAWCIP DAWCOV DAWCUB DAWDAI DAWDEM
# 120 C26H8Cu2N2O12 10.1002/chem.201002135
#  >>> SOME DIFFERENT, REMOVE! ALAMUW ALANAD
# 121 [Cd(btzb)(bib)(H2O)]n·(DMAC)n·(H2O)2n 10.1039/c6ce00057f
#  >>> SOME DIFFERENT, REMOVE! ULIKUX ULILAE ULILEI
# 122 [Cu2(bdc)2(bpy)]n 10.1126/science.1231451
#  >>> SOME DIFFERENT, REMOVE! NEJRUR NEJSAY NEJSEC NEJSIG NEJSOM
# 123 C80H99N25O17Zn5 10.1002/anie.200902274
#  >>> SOME DIFFERENT, REMOVE! KUJNOT KUJNUZ KUJPAH
# 124 [Ni2(C2O4)(L)2]n*6nH2O 10.1021/cg400948e
#  >>> ALL THE SAME! HAHCUR YINSIZ YINSIZ01 YINSUL YINSUL01
# 125 C15H38Gd2N6O25 10.1021/cg900518s
#  >>> SOME DIFFERENT, REMOVE! CUKXOW CUKXUC CUKYAJ CUKYEN FUTZOK
# 126 desolvated [Cu5(L)2(OH)2·(H2O)2·DMA2]·2DMA·EtOH·2H2O 10.1039/c5ce00762c
#  >>> SOME DIFFERENT, REMOVE! HUDWOU HUDWUA
# 127 [{Co2(L)-(bpe)(H2O)}*5H2O]n 10.1021/ja403449k
#  >>> ALL THE SAME! FIFMIS FIFMIS01 FIFMOY FIFMUE
# 128 [Na2(NDA)(DMF)] 10.1039/c3ce42208a
#  >>> SOME DIFFERENT, REMOVE! KIXXIA KIXXOG KIYLUB KIYMAI KIYMEM KIYMIQ
# 129 [Rh(II)2(bza)4(2-epyz)]n 10.1021/ic051952e
#  >>> SOME DIFFERENT, REMOVE! KELCUA KELCUA01 KELDAH KELDEL
# 130 C9H3GdO6 10.1039/c1ce05468f
#  >>> SOME DIFFERENT, REMOVE! EBEWIT EBEWOZ EBEWOZ01 EBEXAM EBEXEQ EBEXEQ01 EBEXIU EBEXIU01 EBEXIU02
# 131 C57H36In3N4O16 10.1038/ncomms3344
#  >>> SOME DIFFERENT, REMOVE! AGOVID AGOVOJ AGOVUP AGOWAW AGOWEA
# 132 MIL-53(Fe) 10.1021/cm301242d
#  >>> SOME DIFFERENT, REMOVE! SETQAL SETQEP SETQIT SETQOZ SETQUF SETRAM
# 133 Zn2C14N2O8H4 10.1021/ja060946u
#  >>> ALL THE SAME! HENYUV HESVOR
# 134 FMOF-1 10.1002/anie.200804739
#  >>> SOME DIFFERENT, REMOVE! COWRUC COWSAJ COWSEN PITYUN01 PITYUN02 QOVFUD QOVGAK
# 135 [Cu2(m-OH)2(bdim)] 10.1039/c3cc46597g
#  >>> SOME DIFFERENT, REMOVE! WIRMUH WIRNAO
# 136  [Cu3L2(mu3-OH)2(mu2-H2O)]·2DMA 10.1039/c4cc06588c
#  >>> SOME DIFFERENT, REMOVE! FOQNIK FOQNOQ FOQNOQ01 FOQNOQ02 FOQNUW FOQNUW01 FOQNUW02 FOQPAE FOQPAE01 FOQPAE02
# 137 C30H36Co2N4O13 10.1039/c2ce25715g
#  >>> ALL THE SAME! WECFAN WECFAN01
# 138 [Li(C6H4NO2)2]*DMF 10.1002/anie.200906322
#  >>> SOME DIFFERENT, REMOVE! XUNGOD XUNGUJ XUNHAQ
# 139 {[Cu(tba)2](DMF)} 10.1021/ja506357n
#  >>> SOME DIFFERENT, REMOVE! ENANIS TUPDIT04
# 140 MAF-66 10.1021/ic301463z
#  >>> SOME DIFFERENT, REMOVE! YEGKIG YEGKOM
# 141 Zn(NO3)2*6H2O 10.1021/ja909629f
#  >>> SOME DIFFERENT, REMOVE! FUMYOC FUMYUI
# 142 C153H159Cl22Fe3N21O82Pr8S4.5Sb24 10.1002/chem.201302292
#  >>> SOME DIFFERENT, REMOVE! TILBIB TILBIB01 TILBOH
# 143 C72H42Ni3N6O13 10.1039/c3sc22222e
#  >>> SOME DIFFERENT, REMOVE! BEPREV BEPREV01 BEPREV02 BEPREV03 BEPRIZ BEPROF KEVBIY KEVBOE KEVBUK KEVBUK01 KEVCEV
# 144 Desolvated C102H158O25N24F6Ni3 10.1021/cg2002157
#  >>> SOME DIFFERENT, REMOVE! IWESIN IWESOT
# 145 [Co2(ndc)2(bpy)] 10.1039/c5sc01796c
#  >>> SOME DIFFERENT, REMOVE! OHEQUP OHEQUP01 OHEQUP02 OHEQUP03 OHEQUP04 OHEQUP05
# 146 [Na2Co(ipa)2]n 10.1021/ic900919w
#  >>> SOME DIFFERENT, REMOVE! LULWUL LULXAS LULXEW LULXIA LULXOG
# 147 C59H63N5O17Zn4 10.1021/ja043756x
#  >>> SOME DIFFERENT, REMOVE! NAPFOA NAPFOA01 NAPFUG
# 148 [Zn3(TCPB)2*2H2O]*2H2O*4DMF 10.1002/asia.201200601
#  >>> SOME DIFFERENT, REMOVE! GICNIR GICNOX
# 149 {[Zn(bpydb)(bpy)](DMA)-(EtOH)6}n 10.1021/cg500942g
#  >>> SOME DIFFERENT, REMOVE! YOYBIZ YOYBOF YOYBUL
# 150 Co3(DPyP)3 4DMF 10.1039/c3dt53287a
#  >>> SOME DIFFERENT, REMOVE! GOBLOA GOBLUG
# 151 NOTT-300 10.1038/nchem.2114
#  >>> SOME DIFFERENT, REMOVE! TOXMUQ TOXNAX TOXNEB TOXNIF XUPSAE
# 152 [Cu(bcppm)H2O] 10.1021/ja4032049
#  >>> SOME DIFFERENT, REMOVE! TIVHAJ TIVHAJ01 TIVHAJ02
# 153 [Co2(pbdc)2(bimb)0.5 (H2O)4 (DMF)0.25]n 10.1039/c4ta01900h
#  >>> SOME DIFFERENT, REMOVE! LIDSEY01 XOMCIN XOMCOT XOMCUZ
# 154 Cu-SIP-3 10.1021/ja910600b
#  >>> SOME DIFFERENT, REMOVE! GIKMOD02 GIKMOD03 GIKMOD04 GIKMOD05 GIKMOD06 GIKMOD07 GIKMOD08 GIKMOD09 GIKMOD10 GIKMOD11 GIKMOD12 HUCBOX01 HUCBOX02 LUSZIJ LUSZIJ01 LUSZOP LUSZOP01 LUSZUV LUTBEI LUTBUY LUTCAF LUTCEJ LUTCIN LUTDAG
# 155 {[Cd(bpndc)(bpy)]}n 10.1002/anie.200705822
#  >>> SOME DIFFERENT, REMOVE! EFANIJ EFANOP
# 156 [Cu2(glu)2(mu-bpp)]*2H2O 10.1039/c3cc44193h
#  >>> ALL THE SAME! MIJBAK MIJBAK01 MIJBAK02 MIJBAK03 MIJBAK04
# 157 LiZnC9H3O6 10.1021/ic902077j
#  >>> SOME DIFFERENT, REMOVE! WAJHIA WAJHOG WAJHUM WAJJAU WAJJEY WAJJEY01 WAJJOI WAJJOI01
# 158 C2H6O6Mg 10.1021/cg800181q
#  >>> SOME DIFFERENT, REMOVE! DOHDOU MGFORD04
# 159 C8H4N6FeNi 10.1021/ja902187d
#  >>> SOME DIFFERENT, REMOVE! LUFQUZ LUFQUZ01 LUFQUZ02 LUFRIO
# 160 CdC15H20N2O7 10.1007/s11426-010-4107-8
#  >>> SOME DIFFERENT, REMOVE! NANYUX02 PARKUQ
# 161 C23H27Cu2N2O11.5 Desolvated 10.1021/cg070144q
#  >>> SOME DIFFERENT, REMOVE! DIKFAF DILKAL
# 162 [Cu4(oba)4(DMF)4] 10.1007/s11426-011-4347-2
#  >>> SOME DIFFERENT, REMOVE! PARNIH PARNON PARNUT
# 163 [H2N(Me)2]2[Zn4(L)2(H2O)1.5] 10.1039/c5qi00025d
#  >>> SOME DIFFERENT, REMOVE! NUCPEI NUCPIM
# 164 Cr3(BTC)2 10.1021/ja1027925
#  >>> SOME DIFFERENT, REMOVE! ZIGFEC ZIGFIG

# %%
df = pd.read_csv("data/step-08.csv")
df[df.note.str.startswith("OneNIST-to-manyCSD")].head(3)
# Out:
#     identifier  ccdc_number                                  formula  \
# 292     ACOCOM     889572.0  (C40 H24 Cu2 N2 O10)n,5.2n(C5 H9 N1 O1)
# 293     ACOCUS     890363.0  (C40 H24 N2 O10 Zn2)n,5.3n(C5 H9 N1 O1)
# 295     ACODAZ     890364.0  (C40 H24 Co2 N2 O10)n,4.6n(C5 H9 N1 O1)
#
#      has_disorder  publication_year     publication_doi   synonyms_orig  \
# 292          True              2012  10.1039/c2cc34840c  ['DUT-49(Cu)']
# 293          True              2012  10.1039/c2cc34840c  ['DUT-49(Zn)']
# 295          True              2012  10.1039/c2cc34840c  ['DUT-49(Co)']
#
#            synonyms                                               note  \
# 292  ['DUT-49(Cu)']  OneNIST-to-manyCSD matches by DOI >> EXCLUDE, ...
# 293  ['DUT-49(Zn)']  OneNIST-to-manyCSD matches by DOI >> EXCLUDE, ...
# 295  ['DUT-49(Co)']  OneNIST-to-manyCSD matches by DOI >> EXCLUDE, ...
#
#     nist_mat nist_mat_by_doi                           sgh_asr
# 292      NaN      ['DUT-49']  16a310f2c3a7af6421186dc7747dca86
# 293      NaN      ['DUT-49']  94b4e7020e7afe887e01388b96c528af
# 295      NaN      ['DUT-49']  d79b2122c49a9f0c3302a9c05240164f

# %%
# Shows statistics
df = pd.read_csv("data/step-08.csv")
df = df.sort_values('note', ascending=True) # When I keep=first, these are sorted by note

print('Statistics by CSD entries')
for note in set(df['note']):
    count = len(df[df.note==note])
    print(count, "\t",note)
    
tot = df[df.note.isin([
    'Matched by synonym', 
    'Matched by synonym (corrected)',
    'One-to-one match by DOI',
    'OneNIST-to-manyCSD matches by DOI >> MATCH, same SGH',
])]  

print("\n Total CSD matched:", len(tot))
    
print()
print('Statistics by NIST matches')
df = df[~pd.isnull(df['nist_mat'])]
df = df[~df.duplicated(subset='nist_mat', keep='first')]
tot=0
for note in set(df['note']):
    count = len(df[df.note==note])
    tot+=count
    print(count, "\t",note)

print("\n Total NIST matched:", tot)
# Out:
# Statistics by CSD entries
# 1913 	 Excluding more than 3 same MOFs from the same DOI
# 500 	 OneNIST-to-manyCSD matches by DOI >> EXCLUDE, different SGH
# 40 	 Matched by synonym (corrected)
# 370 	 Exclude DOI already matched by synonym
# 325 	 One-to-one match by DOI
# 937 	 VariousNIST-to-paper matched by DOI
# 394 	 Matched by synonym
# 83 	 OneNIST-to-manyCSD matches by DOI >> MATCH, same SGH
# 101360 	 -
#
#  Total CSD matched: 842
#
# Statistics by NIST matches
# 302 	 Matched by synonym
# 30 	 OneNIST-to-manyCSD matches by DOI >> MATCH, same SGH
# 319 	 One-to-one match by DOI
# 32 	 Matched by synonym (corrected)
#
#  Total NIST matched: 683
